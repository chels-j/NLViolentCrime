# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import math

# %%
## Extract and print metadata table
meta_csv = '

# %%
## Extract codes for non-grouped features


## Extract and combine codes for grouped features
